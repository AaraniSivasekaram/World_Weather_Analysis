# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f3eca5c9e82de47e5d031331b107ae04

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | lavrentiya
# Processing Record 6 of Set 1 | behbahan
# Processing Record 7 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 1 | dingle
# Processing Record 9 of Set 1 | mount gambier
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | zaokskiy
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | balikpapan
# Processing Record 15 of Set 1 | zemio
# Processing Record 16 of Set 1 | viedma
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | yatou
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | samarai
# Processing Record 22 of Set 1 | sao joao do piaui
# Processing Record 23 of Set 1 | ancud
# Processing Record 24 of Set 1 | fairlie
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | krasnoselkup
# Processing Record 29 of Set 1 | trincomalee
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 1 | buraydah
# Processing Record 34 of Set 1 | marathopolis
# City not found. Skipping...
# Processing Record 35 of Set 1 | luanda
# Processing Record 36 of Set 1 | alofi
# Processing Record 37 of Set 1 | walvis bay
# Processing Record 38 of Set 1 | salamiyah
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | afmadu
# City not found. Skipping...
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | elat
# Processing Record 44 of Set 1 | deputatskiy
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | mardan
# Processing Record 47 of Set 1 | cherskiy
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | nyaunglebin
# Processing Record 1 of Set 2 | tautira
# Processing Record 2 of Set 2 | kloulklubed
# Processing Record 3 of Set 2 | balad
# Processing Record 4 of Set 2 | abu samrah
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | willmar
# Processing Record 10 of Set 2 | nouadhibou
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | shimoda
# Processing Record 13 of Set 2 | palmer
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | biscarrosse
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | bud
# Processing Record 18 of Set 2 | port hardy
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 2 | camocim
# Processing Record 22 of Set 2 | playas
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | narsaq
# Processing Record 25 of Set 2 | shimanovsk
# Processing Record 26 of Set 2 | cholan
# City not found. Skipping...
# Processing Record 27 of Set 2 | kortkeros
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | luderitz
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | sola
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | peabiru
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | tanout
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | kirovskiy
# Processing Record 42 of Set 2 | pizarro
# Processing Record 43 of Set 2 | eregli
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | mount isa
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | umm kaddadah
# Processing Record 48 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 2 | vengerovo
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | eenhana
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | wonthaggi
# Processing Record 5 of Set 3 | aksarka
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | pangnirtung
# Processing Record 8 of Set 3 | torbay
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | kieta
# Processing Record 12 of Set 3 | egvekinot
# Processing Record 13 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 3 | iskateley
# Processing Record 15 of Set 3 | albany
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | birao
# Processing Record 18 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | yakeshi
# Processing Record 22 of Set 3 | bengkulu
# Processing Record 23 of Set 3 | the valley
# Processing Record 24 of Set 3 | honningsvag
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | saint-pierre
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | mogadishu
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | serramanna
# Processing Record 32 of Set 3 | nuuk
# Processing Record 33 of Set 3 | xilopolis
# Processing Record 34 of Set 3 | mazagao
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | la tuque
# Processing Record 39 of Set 3 | hangu
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | asau
# Processing Record 42 of Set 3 | chapais
# Processing Record 43 of Set 3 | hofn
# Processing Record 44 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 3 | bonavista
# Processing Record 46 of Set 3 | portland
# Processing Record 47 of Set 3 | zapolyarnyy
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | kutum
# Processing Record 50 of Set 3 | borgarnes
# Processing Record 1 of Set 4 | saint anthony
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | klaksvik
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | mbini
# Processing Record 6 of Set 4 | kamenka
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | presidencia roque saenz pena
# Processing Record 9 of Set 4 | bilibino
# Processing Record 10 of Set 4 | tokzar
# City not found. Skipping...
# Processing Record 11 of Set 4 | dandong
# Processing Record 12 of Set 4 | moron
# Processing Record 13 of Set 4 | oxapampa
# Processing Record 14 of Set 4 | aklavik
# Processing Record 15 of Set 4 | sao joao da barra
# Processing Record 16 of Set 4 | lukaya
# Processing Record 17 of Set 4 | wahpeton
# Processing Record 18 of Set 4 | bougouni
# Processing Record 19 of Set 4 | upington
# Processing Record 20 of Set 4 | kahului
# Processing Record 21 of Set 4 | nyrob
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | hailey
# Processing Record 25 of Set 4 | menongue
# Processing Record 26 of Set 4 | atbasar
# Processing Record 27 of Set 4 | huilong
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | grindavik
# Processing Record 30 of Set 4 | roquetas de mar
# Processing Record 31 of Set 4 | erenhot
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | tamorong
# Processing Record 34 of Set 4 | beringovskiy
# Processing Record 35 of Set 4 | porto nacional
# Processing Record 36 of Set 4 | nemuro
# Processing Record 37 of Set 4 | cedar city
# Processing Record 38 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 4 | luganville
# Processing Record 40 of Set 4 | helong
# Processing Record 41 of Set 4 | seondha
# Processing Record 42 of Set 4 | henderson
# Processing Record 43 of Set 4 | mitsamiouli
# Processing Record 44 of Set 4 | pevek
# Processing Record 45 of Set 4 | rocha
# Processing Record 46 of Set 4 | iquitos
# Processing Record 47 of Set 4 | azuaga
# Processing Record 48 of Set 4 | khatanga
# Processing Record 49 of Set 4 | uthal
# Processing Record 50 of Set 4 | tuscaloosa
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | sayyan
# Processing Record 3 of Set 5 | foundiougne
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | olafsvik
# Processing Record 6 of Set 5 | nago
# Processing Record 7 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 8 of Set 5 | salalah
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | bayan
# Processing Record 13 of Set 5 | moose factory
# Processing Record 14 of Set 5 | inirida
# Processing Record 15 of Set 5 | levelland
# Processing Record 16 of Set 5 | malayal
# Processing Record 17 of Set 5 | vao
# Processing Record 18 of Set 5 | mikhaylovskaya
# Processing Record 19 of Set 5 | port moresby
# Processing Record 20 of Set 5 | ambon
# Processing Record 21 of Set 5 | kapit
# Processing Record 22 of Set 5 | zhangzhou
# Processing Record 23 of Set 5 | hovd
# Processing Record 24 of Set 5 | taloqan
# Processing Record 25 of Set 5 | marawi
# Processing Record 26 of Set 5 | auki
# Processing Record 27 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 5 | eureka
# Processing Record 29 of Set 5 | chokurdakh
# Processing Record 30 of Set 5 | borlange
# City not found. Skipping...
# Processing Record 31 of Set 5 | namibe
# Processing Record 32 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 5 | ponta do sol
# Processing Record 34 of Set 5 | cockburn town
# Processing Record 35 of Set 5 | sitka
# Processing Record 36 of Set 5 | norman wells
# Processing Record 37 of Set 5 | telimele
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | teruel
# Processing Record 40 of Set 5 | cabra
# Processing Record 41 of Set 5 | flinders
# Processing Record 42 of Set 5 | puerto leguizamo
# Processing Record 43 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 44 of Set 5 | omsukchan
# Processing Record 45 of Set 5 | jackson
# Processing Record 46 of Set 5 | baykit
# Processing Record 47 of Set 5 | nuevo progreso
# Processing Record 48 of Set 5 | klokkarvik
# City not found. Skipping...
# Processing Record 49 of Set 5 | hammerfest
# Processing Record 50 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 1 of Set 6 | saldanha
# Processing Record 2 of Set 6 | sorong
# Processing Record 3 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 6 | hanko
# Processing Record 5 of Set 6 | dogondoutchi
# Processing Record 6 of Set 6 | cayenne
# Processing Record 7 of Set 6 | veraval
# Processing Record 8 of Set 6 | siilinjarvi
# Processing Record 9 of Set 6 | muisne
# Processing Record 10 of Set 6 | bay roberts
# Processing Record 11 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 6 | ryazan
# Processing Record 13 of Set 6 | shirokiy
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | gazojak
# Processing Record 16 of Set 6 | marzuq
# Processing Record 17 of Set 6 | estelle
# Processing Record 18 of Set 6 | provideniya
# Processing Record 19 of Set 6 | rabo de peixe
# Processing Record 20 of Set 6 | meadow lake
# Processing Record 21 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 6 | lovozero
# Processing Record 23 of Set 6 | vanavara
# Processing Record 24 of Set 6 | talnakh
# Processing Record 25 of Set 6 | camacha
# Processing Record 26 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 27 of Set 6 | buala
# Processing Record 28 of Set 6 | dharchula
# Processing Record 29 of Set 6 | lima
# Processing Record 30 of Set 6 | progreso
# Processing Record 31 of Set 6 | santa cruz
# Processing Record 32 of Set 6 | havre-saint-pierre
# Processing Record 33 of Set 6 | chazuta
# Processing Record 34 of Set 6 | clyde river
# Processing Record 35 of Set 6 | lasa
# Processing Record 36 of Set 6 | pembroke
# Processing Record 37 of Set 6 | hampton
# Processing Record 38 of Set 6 | racine
# Processing Record 39 of Set 6 | tual
# Processing Record 40 of Set 6 | sinazongwe
# Processing Record 41 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 42 of Set 6 | pisco
# Processing Record 43 of Set 6 | kiama
# Processing Record 44 of Set 6 | vallecillo
# Processing Record 45 of Set 6 | kattivakkam
# Processing Record 46 of Set 6 | santiago
# Processing Record 47 of Set 6 | ahuimanu
# Processing Record 48 of Set 6 | vredendal
# Processing Record 49 of Set 6 | port augusta
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 1 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 7 | vallenar
# Processing Record 3 of Set 7 | maungatapere
# Processing Record 4 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 7 | kondinskoye
# Processing Record 6 of Set 7 | sochi
# Processing Record 7 of Set 7 | cap malheureux
# Processing Record 8 of Set 7 | aitape
# Processing Record 9 of Set 7 | dagana
# Processing Record 10 of Set 7 | yuancheng
# Processing Record 11 of Set 7 | ahipara
# Processing Record 12 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 7 | bathsheba
# Processing Record 14 of Set 7 | troitsko-pechorsk
# Processing Record 15 of Set 7 | ribeira grande
# Processing Record 16 of Set 7 | katsuura
# Processing Record 17 of Set 7 | chandler
# Processing Record 18 of Set 7 | zhigansk
# Processing Record 19 of Set 7 | la ronge
# Processing Record 20 of Set 7 | severo-kurilsk
# Processing Record 21 of Set 7 | arman
# Processing Record 22 of Set 7 | vardo
# Processing Record 23 of Set 7 | henties bay
# Processing Record 24 of Set 7 | sinnamary
# Processing Record 25 of Set 7 | los llanos de aridane
# Processing Record 26 of Set 7 | ambilobe
# Processing Record 27 of Set 7 | sorland
# Processing Record 28 of Set 7 | iberia
# Processing Record 29 of Set 7 | faanui
# Processing Record 30 of Set 7 | ozinki
# Processing Record 31 of Set 7 | sovetskaya gavan
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | saint-augustin
# Processing Record 34 of Set 7 | omboue
# Processing Record 35 of Set 7 | saint-joseph
# Processing Record 36 of Set 7 | batemans bay
# Processing Record 37 of Set 7 | bosanski brod
# Processing Record 38 of Set 7 | isangel
# Processing Record 39 of Set 7 | souillac
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | rio cuarto
# Processing Record 42 of Set 7 | nongstoin
# Processing Record 43 of Set 7 | san patricio
# Processing Record 44 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 7 | braganca
# Processing Record 46 of Set 7 | acurenam
# Processing Record 47 of Set 7 | morros
# Processing Record 48 of Set 7 | white rock
# Processing Record 49 of Set 7 | dina
# Processing Record 50 of Set 7 | goderich
# Processing Record 1 of Set 8 | malinovoye ozero
# Processing Record 2 of Set 8 | nome
# Processing Record 3 of Set 8 | sabha
# Processing Record 4 of Set 8 | bambous virieux
# Processing Record 5 of Set 8 | koshurnikovo
# Processing Record 6 of Set 8 | lisakovsk
# Processing Record 7 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 8 | miyazu
# Processing Record 9 of Set 8 | fairbanks
# Processing Record 10 of Set 8 | santa rosalia
# Processing Record 11 of Set 8 | kabinda
# Processing Record 12 of Set 8 | panzhihua
# Processing Record 13 of Set 8 | rio de mouro
# Processing Record 14 of Set 8 | yar-sale
# Processing Record 15 of Set 8 | dauphin
# Processing Record 16 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 17 of Set 8 | longyearbyen
# Processing Record 18 of Set 8 | xian
# Processing Record 19 of Set 8 | basoko
# Processing Record 20 of Set 8 | laguna de duero
# Processing Record 21 of Set 8 | antropovo
# Processing Record 22 of Set 8 | nizhniy bestyakh
# Processing Record 23 of Set 8 | flin flon
# Processing Record 24 of Set 8 | stornoway
# Processing Record 25 of Set 8 | bolshaya dzhalga
# Processing Record 26 of Set 8 | praia da vitoria
# Processing Record 27 of Set 8 | sao jose da coroa grande
# Processing Record 28 of Set 8 | sangueya
# Processing Record 29 of Set 8 | mbeya
# Processing Record 30 of Set 8 | muros
# Processing Record 31 of Set 8 | mahaicony
# City not found. Skipping...
# Processing Record 32 of Set 8 | port macquarie
# Processing Record 33 of Set 8 | udgir
# Processing Record 34 of Set 8 | te anau
# Processing Record 35 of Set 8 | atikokan
# Processing Record 36 of Set 8 | mehamn
# Processing Record 37 of Set 8 | salym
# Processing Record 38 of Set 8 | leningradskiy
# Processing Record 39 of Set 8 | cavalcante
# Processing Record 40 of Set 8 | liverpool
# Processing Record 41 of Set 8 | san policarpo
# Processing Record 42 of Set 8 | boa vista
# Processing Record 43 of Set 8 | grand gaube
# Processing Record 44 of Set 8 | nara
# Processing Record 45 of Set 8 | warora
# Processing Record 46 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 8 | khelyulya
# Processing Record 48 of Set 8 | adrar
# Processing Record 49 of Set 8 | srednekolymsk
# Processing Record 50 of Set 8 | caluquembe
# Processing Record 1 of Set 9 | roros
# Processing Record 2 of Set 9 | mirador
# Processing Record 3 of Set 9 | burica
# City not found. Skipping...
# Processing Record 4 of Set 9 | richards bay
# Processing Record 5 of Set 9 | camabatela
# Processing Record 6 of Set 9 | sterlitamak
# Processing Record 7 of Set 9 | san pedro
# Processing Record 8 of Set 9 | ambanja
# Processing Record 9 of Set 9 | paamiut
# Processing Record 10 of Set 9 | balabac
# Processing Record 11 of Set 9 | guerrero negro
# Processing Record 12 of Set 9 | beaverlodge
# Processing Record 13 of Set 9 | talavera
# Processing Record 14 of Set 9 | bhadrachalam
# Processing Record 15 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 9 | campoverde
# Processing Record 17 of Set 9 | gizo
# Processing Record 18 of Set 9 | umea
# Processing Record 19 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | vila velha
# Processing Record 21 of Set 9 | uray
# Processing Record 22 of Set 9 | kralendijk
# Processing Record 23 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 9 | faya
# Processing Record 25 of Set 9 | sijunjung
# Processing Record 26 of Set 9 | ugoofaaru
# Processing Record 27 of Set 9 | abalak
# Processing Record 28 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 9 | chubbuck
# Processing Record 30 of Set 9 | lastoursville
# Processing Record 31 of Set 9 | gouyave
# Processing Record 32 of Set 9 | tabory
# Processing Record 33 of Set 9 | sandpoint
# Processing Record 34 of Set 9 | shache
# Processing Record 35 of Set 9 | tura
# Processing Record 36 of Set 9 | nenjiang
# Processing Record 37 of Set 9 | solotvyn
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | sam roi yot
# Processing Record 40 of Set 9 | lata
# Processing Record 41 of Set 9 | moquegua
# Processing Record 42 of Set 9 | lafiagi
# Processing Record 43 of Set 9 | aksu
# Processing Record 44 of Set 9 | svetlaya
# Processing Record 45 of Set 9 | biak
# Processing Record 46 of Set 9 | pimentel
# Processing Record 47 of Set 9 | meulaboh
# Processing Record 48 of Set 9 | ekibastuz
# Processing Record 49 of Set 9 | ulcinj
# Processing Record 50 of Set 9 | amapa
# Processing Record 1 of Set 10 | powell
# Processing Record 2 of Set 10 | kalmunai
# Processing Record 3 of Set 10 | chimore
# Processing Record 4 of Set 10 | angoche
# Processing Record 5 of Set 10 | moshupa
# Processing Record 6 of Set 10 | zharkent
# Processing Record 7 of Set 10 | damaturu
# Processing Record 8 of Set 10 | varhaug
# Processing Record 9 of Set 10 | amatitan
# Processing Record 10 of Set 10 | venice
# Processing Record 11 of Set 10 | zhytomyr
# Processing Record 12 of Set 10 | elverum
# Processing Record 13 of Set 10 | mecca
# Processing Record 14 of Set 10 | manzanillo
# Processing Record 15 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 10 | tambopata
# Processing Record 17 of Set 10 | tilichiki
# Processing Record 18 of Set 10 | naron
# Processing Record 19 of Set 10 | becsehely
# Processing Record 20 of Set 10 | kavieng
# Processing Record 21 of Set 10 | thinadhoo
# Processing Record 22 of Set 10 | kandrian
# Processing Record 23 of Set 10 | kihurio
# Processing Record 24 of Set 10 | gayeri
# Processing Record 25 of Set 10 | zuenoula
# Processing Record 26 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 27 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | silver city
# Processing Record 29 of Set 10 | andenes
# Processing Record 30 of Set 10 | bowen
# Processing Record 31 of Set 10 | ewa beach
# Processing Record 32 of Set 10 | noumea
# Processing Record 33 of Set 10 | carnot
# Processing Record 34 of Set 10 | mezen
# Processing Record 35 of Set 10 | aripuana
# Processing Record 36 of Set 10 | berlevag
# Processing Record 37 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 10 | northam
# Processing Record 39 of Set 10 | mamlyutka
# Processing Record 40 of Set 10 | talisayan
# Processing Record 41 of Set 10 | sisimiut
# Processing Record 42 of Set 10 | pangai
# Processing Record 43 of Set 10 | oranjemund
# Processing Record 44 of Set 10 | xichang
# Processing Record 45 of Set 10 | solano
# Processing Record 46 of Set 10 | lac du bonnet
# Processing Record 47 of Set 10 | zhangye
# Processing Record 48 of Set 10 | hailar
# Processing Record 49 of Set 10 | tignere
# Processing Record 50 of Set 10 | imuris
# Processing Record 1 of Set 11 | terrace
# Processing Record 2 of Set 11 | georgetown
# Processing Record 3 of Set 11 | vylgort
# City not found. Skipping...
# Processing Record 4 of Set 11 | macusani
# Processing Record 5 of Set 11 | port-gentil
# Processing Record 6 of Set 11 | zaraysk
# Processing Record 7 of Set 11 | leshukonskoye
# Processing Record 8 of Set 11 | amposta
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | atasu
# Processing Record 11 of Set 11 | sur
# Processing Record 12 of Set 11 | prainha
# Processing Record 13 of Set 11 | daru
# Processing Record 14 of Set 11 | bontang
# Processing Record 15 of Set 11 | pangody
# Processing Record 16 of Set 11 | hami
# Processing Record 17 of Set 11 | yumen
# Processing Record 18 of Set 11 | las vegas
# Processing Record 19 of Set 11 | dicabisagan
# Processing Record 20 of Set 11 | udachnyy
# Processing Record 21 of Set 11 | seymchan
# Processing Record 22 of Set 11 | okhotsk
# Processing Record 23 of Set 11 | tukums
# Processing Record 24 of Set 11 | constitucion
# Processing Record 25 of Set 11 | igunga
# Processing Record 26 of Set 11 | karabuk
# Processing Record 27 of Set 11 | moyale
# Processing Record 28 of Set 11 | diffa
# Processing Record 29 of Set 11 | sonoita
# Processing Record 30 of Set 11 | grootfontein
# Processing Record 31 of Set 11 | kudahuvadhoo
# Processing Record 32 of Set 11 | dankov
# Processing Record 33 of Set 11 | boende
# Processing Record 34 of Set 11 | pacifica
# Processing Record 35 of Set 11 | gairo
# Processing Record 36 of Set 11 | spartanburg
# Processing Record 37 of Set 11 | karratha
# Processing Record 38 of Set 11 | marrakesh
# Processing Record 39 of Set 11 | broome
# Processing Record 40 of Set 11 | smithers
# Processing Record 41 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 11 | dunmore town
# Processing Record 43 of Set 11 | monduli
# Processing Record 44 of Set 11 | hambantota
# Processing Record 45 of Set 11 | mixtepec
# City not found. Skipping...
# Processing Record 46 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 11 | husavik
# Processing Record 48 of Set 11 | north bend
# Processing Record 49 of Set 11 | makaryev
# Processing Record 50 of Set 11 | korla
# Processing Record 1 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 12 | gamba
# Processing Record 3 of Set 12 | carballo
# Processing Record 4 of Set 12 | otavalo
# Processing Record 5 of Set 12 | mazyr
# Processing Record 6 of Set 12 | butte
# Processing Record 7 of Set 12 | den helder
# Processing Record 8 of Set 12 | riviere-au-renard
# Processing Record 9 of Set 12 | upata
# Processing Record 10 of Set 12 | turukhansk
# Processing Record 11 of Set 12 | mioveni
# Processing Record 12 of Set 12 | miles city
# Processing Record 13 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 12 | tessalit
# Processing Record 15 of Set 12 | shumskiy
# Processing Record 16 of Set 12 | haines junction
# Processing Record 17 of Set 12 | quatre cocos
# Processing Record 18 of Set 12 | shingu
# Processing Record 19 of Set 12 | senneterre
# Processing Record 20 of Set 12 | tazovskiy
# Processing Record 21 of Set 12 | kazachinskoye
# Processing Record 22 of Set 12 | tarbes
# Processing Record 23 of Set 12 | peniche
# Processing Record 24 of Set 12 | sibolga
# Processing Record 25 of Set 12 | naze
# Processing Record 26 of Set 12 | wyszkow
# Processing Record 27 of Set 12 | bereda
# Processing Record 28 of Set 12 | ketchikan
# Processing Record 29 of Set 12 | linxia
# Processing Record 30 of Set 12 | ostrovnoy
# Processing Record 31 of Set 12 | puerto escondido
# Processing Record 32 of Set 12 | harper
# Processing Record 33 of Set 12 | aswan
# Processing Record 34 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 12 | takoradi
# Processing Record 36 of Set 12 | spearfish
# Processing Record 37 of Set 12 | brigham city
# Processing Record 38 of Set 12 | hecun
# Processing Record 39 of Set 12 | yuxia
# Processing Record 40 of Set 12 | vila franca do campo
# Processing Record 41 of Set 12 | makakilo city
# Processing Record 42 of Set 12 | sao domingos
# Processing Record 43 of Set 12 | corner brook
# Processing Record 44 of Set 12 | mayo
# Processing Record 45 of Set 12 | svetlyy
# Processing Record 46 of Set 12 | comodoro rivadavia
# Processing Record 47 of Set 12 | eldorado
# Processing Record 48 of Set 12 | aulla
# Processing Record 49 of Set 12 | mao
# Processing Record 50 of Set 12 | nyurba
# Processing Record 1 of Set 13 | nizwa
# Processing Record 2 of Set 13 | kabugao
# Processing Record 3 of Set 13 | brae
# Processing Record 4 of Set 13 | adre
# Processing Record 5 of Set 13 | ziro
# Processing Record 6 of Set 13 | massakory
# Processing Record 7 of Set 13 | san quintin
# Processing Record 8 of Set 13 | vostok
# Processing Record 9 of Set 13 | plouzane
# Processing Record 10 of Set 13 | sangar
# Processing Record 11 of Set 13 | jiuquan
# Processing Record 12 of Set 13 | shahr-e babak
# Processing Record 13 of Set 13 | olinda
# Processing Record 14 of Set 13 | grinties
# Processing Record 15 of Set 13 | tatsinskaya
# City not found. Skipping...
# Processing Record 16 of Set 13 | mbuji-mayi
# Processing Record 17 of Set 13 | zaysan
# Processing Record 18 of Set 13 | vanimo
# Processing Record 19 of Set 13 | coihaique
# Processing Record 20 of Set 13 | talara
# Processing Record 21 of Set 13 | maniitsoq
# Processing Record 22 of Set 13 | tokur
# Processing Record 23 of Set 13 | wladyslawowo
# Processing Record 24 of Set 13 | winchester
# Processing Record 25 of Set 13 | teplodar
# Processing Record 26 of Set 13 | isernia
# Processing Record 27 of Set 13 | raudeberg
# Processing Record 28 of Set 13 | yulara
# Processing Record 29 of Set 13 | kurilsk
# Processing Record 30 of Set 13 | vestmanna
# Processing Record 31 of Set 13 | kidal
# Processing Record 32 of Set 13 | avera
# Processing Record 33 of Set 13 | olginskaya
# Processing Record 34 of Set 13 | brazzaville
# Processing Record 35 of Set 13 | pottsville
# Processing Record 36 of Set 13 | abu dhabi
# Processing Record 37 of Set 13 | yining
# Processing Record 38 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 13 | kisangani
# Processing Record 40 of Set 13 | palana
# Processing Record 41 of Set 13 | beloha
# Processing Record 42 of Set 13 | dolzhanskaya
# Processing Record 43 of Set 13 | sherbakul
# Processing Record 44 of Set 13 | shadegan
# Processing Record 45 of Set 13 | nhulunbuy
# Processing Record 46 of Set 13 | santa rita
# Processing Record 47 of Set 13 | jacareacanga
# Processing Record 48 of Set 13 | vyartsilya
# Processing Record 49 of Set 13 | inverell
# Processing Record 50 of Set 13 | puerto lempira
# Processing Record 1 of Set 14 | onega
# Processing Record 2 of Set 14 | gumla
# Processing Record 3 of Set 14 | pasighat
# Processing Record 4 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 14 | yithion
# City not found. Skipping...
# Processing Record 6 of Set 14 | nelson bay
# Processing Record 7 of Set 14 | itarema
# Processing Record 8 of Set 14 | khagaria
# Processing Record 9 of Set 14 | solnechnyy
# Processing Record 10 of Set 14 | urumqi
# Processing Record 11 of Set 14 | la macarena
# Processing Record 12 of Set 14 | acapulco
# Processing Record 13 of Set 14 | tamandare
# Processing Record 14 of Set 14 | fayaoue
# Processing Record 15 of Set 14 | maceio
# Processing Record 16 of Set 14 | chernyshevskiy
# Processing Record 17 of Set 14 | vestmannaeyjar
# Processing Record 18 of Set 14 | suntar
# Processing Record 19 of Set 14 | sirnak
# Processing Record 20 of Set 14 | cove
# Processing Record 21 of Set 14 | alcantara
# Processing Record 22 of Set 14 | tucupita
# Processing Record 23 of Set 14 | igrim
# Processing Record 24 of Set 14 | mount pleasant
# Processing Record 25 of Set 14 | mangai
# Processing Record 26 of Set 14 | nokaneng
# Processing Record 27 of Set 14 | kjollefjord
# Processing Record 28 of Set 14 | north fort myers
# Processing Record 29 of Set 14 | mahanoro
# Processing Record 30 of Set 14 | ilulissat
# Processing Record 31 of Set 14 | qeshm
# Processing Record 32 of Set 14 | mizdah
# Processing Record 33 of Set 14 | hun
# Processing Record 34 of Set 14 | ginda
# Processing Record 35 of Set 14 | serravalle pistoiese
# Processing Record 36 of Set 14 | diego de almagro
# Processing Record 37 of Set 14 | arlit
# Processing Record 38 of Set 14 | konjic
# Processing Record 39 of Set 14 | pingliang
# Processing Record 40 of Set 14 | cochrane
# Processing Record 41 of Set 14 | mahibadhoo
# Processing Record 42 of Set 14 | plettenberg bay
# Processing Record 43 of Set 14 | oussouye
# Processing Record 44 of Set 14 | dawei
# Processing Record 45 of Set 14 | kununurra
# Processing Record 46 of Set 14 | tiznit
# Processing Record 47 of Set 14 | san cristobal
# Processing Record 48 of Set 14 | salinopolis
# Processing Record 49 of Set 14 | lewisporte
# Processing Record 50 of Set 14 | waynesboro
# Processing Record 1 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 15 | dunedin
# Processing Record 3 of Set 15 | pimampiro
# Processing Record 4 of Set 15 | riyadh
# Processing Record 5 of Set 15 | kavaratti
# Processing Record 6 of Set 15 | yeppoon
# Processing Record 7 of Set 15 | hervey bay
# Processing Record 8 of Set 15 | corowa
# Processing Record 9 of Set 15 | la maddalena
# Processing Record 10 of Set 15 | jiwani
# Processing Record 11 of Set 15 | tyrma
# Processing Record 12 of Set 15 | seabra
# Processing Record 13 of Set 15 | buckeye
# Processing Record 14 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 15 of Set 15 | baker city
# Processing Record 16 of Set 15 | miri
# Processing Record 17 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 15 | abu kamal
# Processing Record 19 of Set 15 | champerico
# Processing Record 20 of Set 15 | wilmington
# Processing Record 21 of Set 15 | viransehir
# Processing Record 22 of Set 15 | ilo
# Processing Record 23 of Set 15 | fougamou
# Processing Record 24 of Set 15 | zeya
# Processing Record 25 of Set 15 | ondangwa
# Processing Record 26 of Set 15 | dhidhdhoo
# Processing Record 27 of Set 15 | bubaque
# Processing Record 28 of Set 15 | teguldet
# Processing Record 29 of Set 15 | coquimbo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Puerto Ayora  -0.7393  -90.3518     82.40        74          75
# 1        Rikitea -23.1203 -134.9692     77.81        73          96
# 2           Lebu -37.6167  -73.6500     60.71        87          24
# 3        Ushuaia -54.8000  -68.3000     60.80        59           0
# 4     Lavrentiya  65.5833 -171.0000     -8.27        85           0
# 5       Behbahan  30.5959   50.2417     44.60        93           0
# 6         Dingle  10.9995  122.6711     76.06        91         100
# 7  Mount Gambier -37.8333  140.7667     57.20        67          90
# 8        Mataura -46.1927  168.8643     70.38        46          99
# 9       Zaokskiy  54.7306   37.4089      3.00        94          99
#
#    Wind Speed Country Current Description
# 0       13.80      EC          light rain
# 1       12.97      PF     overcast clouds
# 2        3.65      CL          few clouds
# 3        4.61      AR           clear sky
# 4        7.85      RU           clear sky
# 5        2.19      IR           clear sky
# 6        9.22      PH     overcast clouds
# 7       10.36      AU     overcast clouds
# 8        3.13      NZ     overcast clouds
# 9        7.49      RU     overcast clouds

# %%
# Rearrange DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Puerto Ayora      EC  -0.7393  -90.3518     82.40        74          75
# 1        Rikitea      PF -23.1203 -134.9692     77.81        73          96
# 2           Lebu      CL -37.6167  -73.6500     60.71        87          24
# 3        Ushuaia      AR -54.8000  -68.3000     60.80        59           0
# 4     Lavrentiya      RU  65.5833 -171.0000     -8.27        85           0
# 5       Behbahan      IR  30.5959   50.2417     44.60        93           0
# 6         Dingle      PH  10.9995  122.6711     76.06        91         100
# 7  Mount Gambier      AU -37.8333  140.7667     57.20        67          90
# 8        Mataura      NZ -46.1927  168.8643     70.38        46          99
# 9       Zaokskiy      RU  54.7306   37.4089      3.00        94          99
#
#    Wind Speed Current Description
# 0       13.80          light rain
# 1       12.97     overcast clouds
# 2        3.65          few clouds
# 3        4.61           clear sky
# 4        7.85           clear sky
# 5        2.19           clear sky
# 6        9.22     overcast clouds
# 7       10.36     overcast clouds
# 8        3.13     overcast clouds
# 9        7.49     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
